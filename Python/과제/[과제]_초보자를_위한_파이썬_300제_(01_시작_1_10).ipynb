# %% [markdown]
# <a href="https://colab.research.google.com/github/mongdaeng/est-wassup1/blob/main/%5B%EA%B3%BC%EC%A0%9C%5D_%EC%B4%88%EB%B3%B4%EC%9E%90%EB%A5%BC_%EC%9C%84%ED%95%9C_%ED%8C%8C%EC%9D%B4%EC%8D%AC_300%EC%A0%9C_(01_%EC%8B%9C%EC%9E%91_1_10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("C:\windows")
# Out:
# C:\windows

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("안녕하세요.\n만나서\t\t반갑습니다.")

#\n은 줄바꿈
#\t는 탭
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print ("오늘은","일요일")

#여러 값을 출력하려면, print 함수에서 쉼표로 구분
# Out:
# 오늘은 일요일

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("naver;kakao;sk;samsung")
# Out:
# naver;kakao;sk;samsung

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("naver/kakao/sk/samsung")
# Out:
# naver/kakao/sk/samsung

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print("first", end=""); print("second")
#end='' 줄바꿈 대신 옆으로 붙여주는 옵션
# Out:
# firstsecond

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(5/3)
# Out:
# 1.6666666666666667
